# %%
import pandas as pd

data = pd.read_csv('search_strings.csv', encoding = "ISO-8859-1")
data['item_title'] = data['item_title'].str.lower()

# %%
clean_data = data[['item_title', 'category']]

clean_data
# Out:
#                                               item_title  \
# 0      auto window sun shade sock cover baby child uv...
# 1      epoxy resin 16 oz kit crystal clear for super ...
# 2      crystal clear epoxy resin general purpose bar ...
# 3      crystal clear epoxy resin general purpose bar ...
# 4      * plastic casting resin for casting in silicon...
# 5      flex seal clear jumbo can liquid rubber spray ...
# 6       ultra clear epoxy resin - fiberglass, table t...
# 7      flex seal black jumbo can liquid rubber spray ...
# 8      crystal clear bar table top epoxy resin coatin...
# 9      ultra-low viscosity liquid plastic urethane ca...
# 10      ultra clear epoxy resin - bar tops, table top...
# 11     fiberfix hi temp heat wrap fiber fix 2" x 70" ...
# 12     epoxy resin 32 oz kit crystal clear for super ...
# 13      plastic acrylic plexiglass cement glue weldon...
# 14      ultra clear epoxy resin - bar tops, table top...
# ...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer(stop_words='english')
X = vectorizer.fit_transform(clean_data['item_title'])

# %%
print(vectorizer.get_stop_words())
# Out:
# frozenset({'around', 'where', 'our', 'anything', 'though', 'done', 'not', 'has', 'once', 'so', 'con', 'be', 'else', 'we', 'under', 'themselves', 'many', 'front', 'find', 'otherwise', 'a', 'go', 'moreover', 'whatever', 'since', 'here', 'only', 'whoever', 'against', 'eg', 'get', 'often', 'seemed', 'top', 'empty', 'i', 'everything', 'others', 'ours', 'other', 'call', 'should', 'its', 'almost', 'anyone', 'none', 'last', 'back', 'own', 'the', 'with', 'by', 'several', 'or', 'eleven', 'sincere', 'thence', 'thru', 'hereafter', 'something', 'up', 'whither', 'hereby', 'my', 'herself', 'beforehand', 'these', 'down', 'alone', 'third', 'either', 'rather', 'cant', 'over', 'us', 'five', 'fifteen', 'out', 'every', 'became', 'sixty', 'until', 'hasnt', 'still', 'whole', 'except', 'but', 'yet', 'again', 'between', 'ourselves', 'such', 'per', 'fifty', 'co', 'for', 'mine', 'off', 'yourselves', 'nor', 'any', 'as', 'there', 'of', 'sometimes', 'nothing', 'behind', 'than', 'whence', 'well', 'whenever', 'towa
# ...

# %%
def tokenize(text):
    arr = text.split()
# Out:
#   File "<ipython-input-27-a37f48d06850>", line 1
#     def tokenize(string):
#                          ^
# SyntaxError: unexpected EOF while parsing

# %%
print(tokenize("3m 1 x 9 ft vhb double sided foam adhesive"))
