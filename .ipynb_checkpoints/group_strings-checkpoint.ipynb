# %%
import pandas as pd
from fuzzy_string_group import fuzzy_group, fuzzy_group_key, linear_fuzzy_group
from Levenshtein import ratio

# %%
import csv

with open('vocabulary.csv', newline='') as csvfile:
    vocab = list(csv.reader(csvfile))
    vocab = vocab[0]

# %%
vocab.sort()

# %%
print(vocab)
# Out:
# ['aa', 'aaa', 'aaabu', 'aaahh', 'aakg', 'ab', 'abbey', 'abe', 'abercrombie', 'ability', 'able', 'abn', 'about', 'above', 'abp', 'abs', 'absinthe', 'absolute', 'absorbent', 'absorption', 'ac', 'acai', 'accent', 'access', 'accessoie', 'accessories', 'accessory', 'accord', 'accu', 'accuracy', 'ace', 'acer', 'acetyl', 'achilles', 'acid', 'acids', 'acme', 'acne', 'acp', 'acr', 'acrylic', 'acs', 'acting', 'action', 'actions', 'activate', 'activated', 'activator', 'active', 'activity', 'actuator', 'actuators', 'acura', 'ad', 'ada', 'adams', 'adapte', 'adapter', 'adapters', 'adaptor', 'add', 'added', 'adderdrene', 'additional', 'additives', 'address', 'adeept', 'adhd', 'adhesive', 'adicross', 'adidas', 'adirondack', 'adj', 'adjust', 'adjustable', 'adjusting', 'adjustment', 'adorable', 'adq', 'adtech', 'adult', 'adults', 'adv', 'advance', 'advanced', 'adventure', 'adventures', 'advertising', 'ae', 'aeg', 'aerb', 'aerobreathe', 'aeromodelling', 'aeron', 'aerosol', 'af', 'afa', 'affliction', 'a
# ...

# %%
groups = linear_fuzzy_group(vocab, 0.8)

# %%
print(groups)
# Out:
# {'aa': ['aa', 'aaa'], 'aaabu': ['aaabu'], 'aaahh': ['aaahh'], 'aakg': ['aakg'], 'ab': ['ab'], 'abbey': ['abbey'], 'abe': ['abe'], 'abercrombie': ['abercrombie'], 'ability': ['ability'], 'able': ['able'], 'abn': ['abn'], 'about': ['about'], 'above': ['above'], 'abp': ['abp'], 'abs': ['abs'], 'absinthe': ['absinthe'], 'absolute': ['absolute'], 'absorbent': ['absorbent'], 'absorption': ['absorption'], 'ac': ['ac'], 'acai': ['acai'], 'accent': ['accent'], 'access': ['access', 'accessoie'], 'accessories': ['accessories', 'accessory'], 'accord': ['accord'], 'accu': ['accu'], 'accuracy': ['accuracy'], 'ace': ['ace', 'acer'], 'acetyl': ['acetyl'], 'achilles': ['achilles'], 'acid': ['acid', 'acids'], 'acme': ['acme'], 'acne': ['acne'], 'acp': ['acp'], 'acr': ['acr'], 'acrylic': ['acrylic'], 'acs': ['acs'], 'acting': ['acting', 'action'], 'actions': ['actions'], 'activate': ['activate', 'activated', 'activator', 'active'], 'activity': ['activity'], 'actuator': ['actuator', 'actuators'], 'acura
# ...

# %%
print(len(vocab))
print(len(groups))
# Out:
# 9827
# 7901

# %%
print(ratio('woman', 'womens'))
# Out:
# 0.8
