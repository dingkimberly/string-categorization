# %%
import pandas as pd
from fuzzy_string_group import fuzzy_group, fuzzy_group_key

# %%
import csv

with open('vocabulary.csv', newline='') as csvfile:
    vocab = list(csv.reader(csvfile))
    vocab = vocab[0]

# %%
vocab.sort()

# %%
print(vocab)
# Out:
# ['aa', 'aaa', 'aaaa', 'aaaaavpp', 'aaahh', 'aaasized', 'aakg', 'ab', 'abbey', 'abercrombie', 'ability', 'abn', 'about', 'above', 'abp', 'abppcs', 'abs', 'absinthe', 'absolute', 'absorbent', 'absorption', 'abspc', 'ac', 'acai', 'accent', 'access', 'accessoie', 'accessories', 'accessory', 'accord', 'accu', 'accuracy', 'acd', 'acdc', 'acdolby', 'ace', 'acer', 'acetyl', 'achilles', 'acid', 'acids', 'acme', 'acne', 'acp', 'acr', 'acrylic', 'acs', 'acting', 'action', 'actionadventure', 'actions', 'activate', 'activated', 'activator', 'active', 'activity', 'actuator', 'actuators', 'acura', 'ad', 'ada', 'adams', 'adapte', 'adapter', 'adapterclip', 'adapterfits', 'adapterpower', 'adapters', 'adaptor', 'add', 'added', 'adderdrene', 'additional', 'additives', 'addon', 'address', 'adeept', 'adhd', 'adhesive', 'adhesivefoam', 'adicross', 'adidas', 'adirondack', 'adj', 'adjust', 'adjustable', 'adjustment', 'adorable', 'adp', 'adq', 'adtech', 'adult', 'adults', 'adv', 'advance', 'advanced', 'adventure', 'adventures', 'advertising', 'ae', 'aeg', 'aenr', 'aerb', 'aerobreathe', 'aeromodelling', 'aeron', 'aerosol', 'af', 'afa', 'afan', 'affliction', 'afl', 'afp', 'afraid', 'african', 'afs', 'after', 'ag', 'age', 'ageing', 'agent', 'ages', 'aggressive', 'aging', 'agm', 'agptek', 'agressive', 'ags', 'ah', 'ahd', 'ahref', 'aid', 'aio', 'air', 'airbag', 'airbed', 'airbender', 'airblown', 'airborne', 'airbrush', 'aircabin', 'aircraf', 'airflow', 'airforce', 'airis', 'airistech', 'airmail', 'airmini', 'airminipro', 'airplane', 'airpods', 'airpro', 'airproretina', 'airsoft', 'airtight', 'airwhite', 'airwolf', 'ak', 'akademiks', 'akribos', 'akwm', 'al', 'aladdin', 'alanine', 'alarm', 'alaska', 'alba', 'albaraka', 'albert', 'alcohol', 'aldo', 'alert', 'alessandro', 'alexa', 'alexander', 'alexandria', 'alfa', 'ali', 'alice', 'alien', 'aliens', 'align', 'alignment', 'aline', 'alive', 'alkaline', 'all', 'allante', 'allcolor', 'allen', 'allergen', 'allergy', 'alligator', 'allinone', 'allis', 'alloy', 'allpurpose', 'allsize', 'allterrain', 'allweather', 'alma', 'almond', 'aloetea', 'aloha', 'alpatronix', 'alpha', 'alphabet', 'alphabetletter', 'alphabets', 'alphabounce', 'alphanumeric', 'alpine', 'alpineswiss', 'also', 'alta', 'altec', 'alternative', 'altitude', 'altura', 'aluminium', 'aluminum', 'always', 'am', 'amana', 'amateur', 'amazing', 'amazon', 'amber', 'amc', 'amd', 'amendment', 'america', 'american', 'ameritac', 'ametek', 'amethyst', 'amfm', 'amg', 'amino', 'ammeter', 'amoled', 'amp', 'amplified', 'amplifier', 'ampm', 'amps', 'amscopekids', 'amsterdam', 'amx', 'amy', 'an', 'anabolic', 'anakin', 'analog', 'analogue', 'anamorphic', 'anamorphiclenslooks', 'anarchy', 'anarchythe', 'anchor', 'ancient', 'and', 'anderson', 'andorid', 'andriod', 'android', 'androidios', 'androidiosiphonesamsunglg', 'andy', 'angel', 'angelina', 'angels', 'angelus', 'angle', 'angled', 'angry', 'anhydrous', 'animal', 'animals', 'animalzeldakirbyprincesstoshi', 'animated', 'anime', 'anki', 'ankle', 'anna', 'anne', 'anniversary', 'annke', 'annovi', 'anode', 'anonovi', 'anonymous', 'another', 'anran', 'answering', 'antenna', 'anthology', 'anthraciteblack', 'anti', 'antibacklash', 'antibacterial', 'anticollision', 'anticosingles', 'antidust', 'antique', 'antiscratch', 'antislip', 'antispy', 'antistatic', 'antitheft', 'antler', 'anvil', 'anxiety', 'any', 'ao', 'aod', 'aoe', 'ap', 'apa', 'apartment', 'aperture', 'apluslift', 'apmbsbc', 'app', 'appearances', 'appetite', 'apple', 'appliances', 'application', 'applicator', 'applicators', 'applied', 'appliqu', 'applique', 'appliques', 'appliquescrafttrim', 'apply', 'appradio', 'apprentice', 'approved', 'approx', 'apps', 'apron', 'aprons', 'aprox', 'apsc', 'aq', 'aqua', 'aquamarine', 'aquarium', 'aquatec', 'aquaterior', 'ar', 'arabesque', 'arabia', 'arb', 'arc', 'arcade', 'arcadia', 'arcan', 'arch', 'archaic', 'archangel', 'archery', 'arches', 'archiver', 'arcmate', 'ard', 'ardell', 'arduino', 'arduinoarmmcu', 'arduinocompatible', 'arduin ...
